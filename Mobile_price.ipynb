# %% [markdown]
# # Mobile Price Dataset

# %% [markdown]
# ## Outline:
#     1.Introduction
#     2.Import Libraries
#     3.Read Dataset
#     4.Preprocessing
#       4.1 Changes Columns Name
#       4.2 See If Have Null & See Summary Statistics
#       4.3 Take a copy from data and work in it
#          4.3.1 Encoding categorical variable to numerics
#          4.3.2 Handling Missing Values
#          4.3.3 Multicolinearity
#       4.4 Splitting the dataset into the Training set ,Validtion set and Test set
#       4.5 Feature Scaling

# %% [markdown]
# ## 1.Introduction

# %% [markdown]
# The price of a product is the most important attribute of marketing that product. One of those products where price matters a lot is a smartphone because it comes with a lot of features so that a company thinks a lot about how to price this mobile which can justify the features and also cover the marketing and manufacturing costs of the mobile. In this article, I will walk you through the task of mobile price classification with Machine Learning using Python.

# %% [markdown]
# ## 2.Import Libraries

# %%
#Import libraries for DataSet 
import os
import numpy as np
import pandas as pd

#Import Libraries for Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 3.Read Dataset

# %%
# Importing data into python from the given csv file
dataset= pd.read_csv('our_dataset.csv')

x = train_dataset.iloc[:,0:21]
y = train_dataset.iloc[:,20]

# %%
print(x)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2   2         20       756  2549     9     7
# 1       0.7        136        3   6        905      1988  2631    17     3
# 2       0.9        145        5   6       1263      1716  2603    11     2
# 3       0.8        131        6   9       1216      1786  2769    16     8
# 4       0.6        141        2  14       1208      1212  1411     8     2
# ...     ...        ...      ...  ..        ...       ...   ...   ...   ...
# 1995    0.8        106        6  14       1222      1890   668    13     4
# 1996    0.2        187        4   3        915      1965  2032    11    10
# 1997    0.7        108        8   3        868      1632  3057     9     1
# 1998    0.1        145        5   5        336       670   869    18    10
# 1999    0.9        168        6  16        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# ...         ...      ...           ...   ...          ...
# 1995         19        1             1     0            0
# 1996         16        1             1     1            2
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [2000 rows x 21 columns]

# %%
print(y)
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
#See Head of our Dataset
print("----------------------------------------------->Head of Dataset<------------------------------------------------------")
print()
dataset.head()
# Out:
# ----------------------------------------------->Head of Dataset<------------------------------------------------------
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1          1.0
# 1        1             1     0          2.0
# 2        1             1     0          2.0
# 3        1             0     0          2.0
# 4        1             1     0          1.0

# %%
#See Tail of our Dataset
print("----------------------------------------------->Tail of Dataset<------------------------------------------------------")
print()
dataset.tail()
# Out:
# ----------------------------------------------->Tail of Dataset<------------------------------------------------------
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  14       1222      1890   668    13     4
# 1996    0.2        187        4   3        915      1965  2032    11    10
# 1997    0.7        108        8   3        868      1632  3057     9     1
# 1998    0.1        145        5   5        336       670   869    18    10
# 1999    0.9        168        6  16        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 1995         19        1             1     0          0.0
# 1996         16        1             1     1          2.0
# 1997          5        1             1     1          3.0
# 1998         19        1             1     1          0.0
# 1999          2        1             1     1          NaN

# %%
#Display information about our dataset
print("------------>Information about the Dataset<------------")
print()
dataset.info()
# Out:
# ------------>Information about the Dataset<------------
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    1997 non-null   float64
# dtypes: float64(3), int64(18)
# memory usage: 328.2 KB

# %%
#Display dtypes about our dataset
print("------------>Dtypes of the Dataset<------------")
print()
dataset.dtypes
# Out:
# ------------>Dtypes of the Dataset<------------
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range      float64
# dtype: object

# %% [markdown]
# ## 4.Preprocessing

# %% [markdown]
# Pre-processing refers to the transformations applied to our data before feeding it to the algorithm. Data Preprocessing is a technique that is used to convert the raw data into a clean data set. In other words, whenever the data is gathered from different sources it is collected in raw format which is not feasible for the analysis.

# %% [markdown]
# ### 4.1 Change Columns Name

# %%
dataset.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
dataset.columns = ['BatteryPow', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
       'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
       'px_width', 'Ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
       'touch_screen', 'wi_fi', 'price_range']

# %%
dataset.columns
# Out:
# Index(['BatteryPow', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'Ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wi_fi', 'price_range'],
#       dtype='object')

# %% [markdown]
# ### 4.2 See If Have Null & See Summary Statistics

# %%
#Checking the missing values in our dataset if any
dataset.isnull().sum()
# Out:
# BatteryPow      0
# blue            0
# clock_speed     0
# dual_sim        0
# fc              0
# four_g          0
# int_memory      0
# m_dep           0
# mobile_wt       0
# n_cores         0
# pc              0
# px_height       0
# px_width        0
# Ram             0
# sc_h            0
# sc_w            0
# talk_time       0
# three_g         0
# touch_screen    0
# wi_fi           0
# price_range     3
# dtype: int64

# %%
#Summary statistics of the training dataset
print("--------------------------------------->Decription of the DataSet<---------------------------------------------------")
print()
pd.DataFrame(dataset.describe())
# Out:
# --------------------------------------->Decription of the DataSet<---------------------------------------------------
#         BatteryPow       blue  clock_speed     dual_sim           fc  \
# count  2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean   1238.518500     0.4950     1.522250     0.509500     4.309500
# std     439.418206     0.5001     0.816004     0.500035     4.341444
# min     501.000000     0.0000     0.500000     0.000000     0.000000
# 25%     851.750000     0.0000     0.700000     0.000000     1.000000
# 50%    1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%    1615.250000     1.0000     2.200000     1.000000     7.000000
# max    1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.521500    32.046500     0.501750   140.249000     4.520500
# std       0.499662    18.145715     0.288416    35.399655     2.287837
# min       0.000000     2.000000     0.100000    80.000000     1.000000
# 25%       0.000000    16.000000     0.200000   109.000000     3.000000
# 50%       1.000000    32.000000     0.500000   141.000000     4.000000
# 75%       1.000000    48.000000     0.800000   170.000000     7.000000
# max       1.000000    64.000000     1.000000   200.000000     8.000000
#
#                 pc    px_height     px_width          Ram         sc_h  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      9.916500   645.108000  1251.515500  2124.213000    12.306500
# std       6.064315   443.780811   432.199447  1084.732044     4.213245
# min       0.000000     0.000000   500.000000   256.000000     5.000000
# 25%       5.000000   282.750000   874.750000  1207.500000     9.000000
# 50%      10.000000   564.000000  1247.000000  2146.500000    12.000000
# 75%      15.000000   947.250000  1633.000000  3064.500000    16.000000
# max      20.000000  1960.000000  1998.000000  3998.000000    19.000000
#
#               sc_w    talk_time      three_g  touch_screen  price_range
# count  2000.000000  2000.000000  2000.000000   2000.000000  1997.000000
# mean      5.767000    11.011000     0.761500      0.503000     1.498748
# std       4.356398     5.463955     0.426273      0.500116     1.118089
# min       0.000000     2.000000     0.000000      0.000000     0.000000
# 25%       2.000000     6.000000     1.000000      0.000000     0.000000
# 50%       5.000000    11.000000     1.000000      1.000000     1.000000
# 75%       9.000000    16.000000     1.000000      1.000000     2.000000
# max      18.000000    20.000000     1.000000      1.000000     3.000000

# %% [markdown]
# ### 4.3 Take a copy from data and work in it

# %%
dataset_cop = dataset.copy()

# %%
# Replacing 0s and 1s in the wi_fi column with the appropriate strings
dataset_cop['wi_fi'] =dataset_cop['wi_fi'].replace(0, 'NoWifi')
dataset_cop['wi_fi'] =dataset_cop['wi_fi'].replace(1, 'Wifi')

# %%
dataset_cop['wi_fi'].unique()
# Out:
# array(['Wifi', 'NoWifi'], dtype=object)

# %%
dataset_cop['blue'] = dataset_cop['blue'].replace(0, 'Noblue')
dataset_cop['blue'] = dataset_cop['blue'].replace(1, 'blue')

# %%
dataset_cop['blue'].unique()
# Out:
# array(['Noblue', 'blue'], dtype=object)

# %%
dataset_cop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   BatteryPow    2000 non-null   int64
#  1   blue          2000 non-null   object
#  2   clock_speed   2000 non-null   float64
#  3   dual_sim      2000 non-null   int64
#  4   fc            2000 non-null   int64
#  5   four_g        2000 non-null   int64
#  6   int_memory    2000 non-null   int64
#  7   m_dep         2000 non-null   float64
#  8   mobile_wt     2000 non-null   int64
#  9   n_cores       2000 non-null   int64
#  10  pc            2000 non-null   int64
#  11  px_height     2000 non-null   int64
#  12  px_width      2000 non-null   int64
#  13  Ram           2000 non-null   int64
#  14  sc_h          2000 non-null   int64
#  15  sc_w          2000 non-null   int64
#  16  talk_time     2000 non-null   int64
#  17  three_g       2000 non-null   int64
#  18  touch_screen  2000 non-null   int64
#  19  wi_fi         2000 non-null   object
#  20  price_range   1997 non-null   float64
# dtypes: float64(3), int64(16), object(2)
# memory usage: 328.2+ KB

# %%
dataset_cop.head()
# Out:
#    BatteryPow    blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0         842  Noblue          2.2         0   1       0           7    0.6
# 1        1021    blue          0.5         1   0       1          53    0.7
# 2         563    blue          0.5         1   2       1          41    0.9
# 3         615    blue          2.5         0   0       0          10    0.8
# 4        1821    blue          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   Ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen   wi_fi  price_range
# 0        0             0    Wifi          1.0
# 1        1             1  NoWifi          2.0
# 2        1             1  NoWifi          2.0
# 3        1             0  NoWifi          2.0
# 4        1             1  NoWifi          1.0

# %% [markdown]
# #### 4.3.1 Encoding categorical variable to numerics

# %%
from sklearn.preprocessing import LabelEncoder
leEncoder= LabelEncoder()
dataset_cop['wi_fi'] = leEncoder.fit_transform(dataset['wi_fi'])

# %%
dataset_cop.head()
# Out:
#    BatteryPow    blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0         842  Noblue          2.2         0   1       0           7    0.6
# 1        1021    blue          0.5         1   0       1          53    0.7
# 2         563    blue          0.5         1   2       1          41    0.9
# 3         615    blue          2.5         0   0       0          10    0.8
# 4        1821    blue          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   Ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wi_fi  price_range
# 0        0             0      1          1.0
# 1        1             1      0          2.0
# 2        1             1      0          2.0
# 3        1             0      0          2.0
# 4        1             1      0          1.0

# %%
map_dict = {'Noblue' : 0,'blue' : 1}
dataset_cop['blue'] = dataset_cop['blue'].map(map_dict);

# %%
dataset_cop.tail()
# Out:
#       BatteryPow  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 1995         794     1          0.5         1   0       1           2    0.8
# 1996        1965     1          2.6         1   0       0          39    0.2
# 1997        1911     0          0.9         1   1       1          36    0.7
# 1998        1512     0          0.9         0   4       1          46    0.1
# 1999         510     1          2.0         1   5       1          45    0.9
#
#       mobile_wt  n_cores  pc  px_height  px_width   Ram  sc_h  sc_w  \
# 1995        106        6  14       1222      1890   668    13     4
# 1996        187        4   3        915      1965  2032    11    10
# 1997        108        8   3        868      1632  3057     9     1
# 1998        145        5   5        336       670   869    18    10
# 1999        168        6  16        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wi_fi  price_range
# 1995         19        1             1      0          0.0
# 1996         16        1             1      1          2.0
# 1997          5        1             1      1          3.0
# 1998         19        1             1      1          0.0
# 1999          2        1             1      1          NaN

# %%
dataset_cop.pc.unique()
# Out:
# array([ 2,  6,  9, 14,  7, 10,  0, 15,  1, 18, 17, 11, 16,  4, 20, 13,  3,
#        19,  8,  5, 12], dtype=int64)

# %%
dataset_cop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   BatteryPow    2000 non-null   int64
#  1   blue          2000 non-null   int64
#  2   clock_speed   2000 non-null   float64
#  3   dual_sim      2000 non-null   int64
#  4   fc            2000 non-null   int64
#  5   four_g        2000 non-null   int64
#  6   int_memory    2000 non-null   int64
#  7   m_dep         2000 non-null   float64
#  8   mobile_wt     2000 non-null   int64
#  9   n_cores       2000 non-null   int64
#  10  pc            2000 non-null   int64
#  11  px_height     2000 non-null   int64
#  12  px_width      2000 non-null   int64
#  13  Ram           2000 non-null   int64
#  14  sc_h          2000 non-null   int64
#  15  sc_w          2000 non-null   int64
#  16  talk_time     2000 non-null   int64
#  17  three_g       2000 non-null   int64
#  18  touch_screen  2000 non-null   int64
#  19  wi_fi         2000 non-null   int32
#  20  price_range   1997 non-null   float64
# dtypes: float64(3), int32(1), int64(17)
# memory usage: 320.4 KB

# %% [markdown]
# #### 4.3.2 Handling Missing Values

# %%
dataset_cop['price_range'].unique()
# Out:
# array([ 1.,  2.,  3.,  0., nan])

# %%
dataset_cop['price_range'].fillna(value=2,inplace=True)

# %%
dataset_cop['price_range'].unique()
# Out:
# array([1., 2., 3., 0.])

# %%
# Recheck for missing values (NaN) in the dataset
dataset_cop.isna().any()
# Out:
# BatteryPow      False
# blue            False
# clock_speed     False
# dual_sim        False
# fc              False
# four_g          False
# int_memory      False
# m_dep           False
# mobile_wt       False
# n_cores         False
# pc              False
# px_height       False
# px_width        False
# Ram             False
# sc_h            False
# sc_w            False
# talk_time       False
# three_g         False
# touch_screen    False
# wi_fi           False
# price_range     False
# dtype: bool

# %%
#When we want to make to our dataset
#dataset['price_range'].fillna(value=2,inplace=True)
#dataset.isna().any()

# %% [markdown]
# #### 4.3.3 Multicolinearity

# %%
dataset.corr()
# Out:
#               BatteryPow      blue  clock_speed  dual_sim        fc    four_g  \
# BatteryPow      1.000000  0.011252     0.011482 -0.041847  0.033334  0.015665
# blue            0.011252  1.000000     0.021419  0.035198  0.003593  0.013443
# clock_speed     0.011482  0.021419     1.000000 -0.001315 -0.000434 -0.043073
# dual_sim       -0.041847  0.035198    -0.001315  1.000000 -0.029123  0.003187
# fc              0.033334  0.003593    -0.000434 -0.029123  1.000000 -0.016560
# four_g          0.015665  0.013443    -0.043073  0.003187 -0.016560  1.000000
# int_memory     -0.004004  0.041177     0.006545 -0.015679 -0.029133  0.008690
# m_dep           0.034085  0.004049    -0.014364 -0.022142 -0.001791 -0.001823
# mobile_wt       0.001844 -0.008605     0.012350 -0.008979  0.023618 -0.016537
# n_cores        -0.029727  0.036161    -0.005724 -0.024658 -0.013356 -0.029706
# pc              0.031441 -0.009952    -0.005245 -0.017143  0.644595 -0.005598
# px_height       0.014901 -0.006872    -0.014523 -0.020875 -0.009990 -0.019236
# px_width       -0.008402 -0.041533    -0.009476  0.014291 -0.005176  0.007448
# Ram            -0.000653  0.026351     0.003443  0.041072  0.015099  0.007313
# sc_h           -0.029959 -0.002952    -0.029078 -0.011949 -0.011014  0.027166
# sc_w           -0.021421  0.000613    -0.007378 -0.016666 -0.012373  0.037005
# talk_time       0.052510  0.013934    -0.011432 -0.039404 -0.006829 -0.046628
# three_g         0.011522 -0.030236    -0.046433 -0.014008  0.001793  0.584246
# touch_screen   -0.010516  0.010061     0.019756 -0.017117 -0.014828  0.016758
# price_range     0.202970  0.020820    -0.007194  0.017272  0.022311  0.014622
#
#               int_memory     m_dep  mobile_wt   n_cores        pc  px_height  \
# BatteryPow     -0.004004  0.034085   0.001844 -0.029727  0.031441   0.014901
# blue            0.041177  0.004049  -0.008605  0.036161 -0.009952  -0.006872
# clock_speed     0.006545 -0.014364   0.012350 -0.005724 -0.005245  -0.014523
# dual_sim       -0.015679 -0.022142  -0.008979 -0.024658 -0.017143  -0.020875
# fc             -0.029133 -0.001791   0.023618 -0.013356  0.644595  -0.009990
# four_g          0.008690 -0.001823  -0.016537 -0.029706 -0.005598  -0.019236
# int_memory      1.000000  0.006886  -0.034214 -0.028310 -0.033273   0.010441
# m_dep           0.006886  1.000000   0.021756 -0.003504  0.026282   0.025263
# mobile_wt      -0.034214  0.021756   1.000000 -0.018989  0.018844   0.000939
# n_cores        -0.028310 -0.003504  -0.018989  1.000000 -0.001193  -0.006872
# pc             -0.033273  0.026282   0.018844 -0.001193  1.000000  -0.018465
# px_height       0.010441  0.025263   0.000939 -0.006872 -0.018465   1.000000
# px_width       -0.008335  0.023566   0.000090  0.024480  0.004196   0.510664
# Ram             0.032813 -0.009434  -0.002581  0.004868  0.028984  -0.020352
# sc_h            0.037771 -0.025348  -0.033855 -0.000315  0.004938   0.059615
# sc_w            0.011731 -0.018388  -0.020761  0.025826 -0.023819   0.043038
# talk_time      -0.002790  0.017003   0.006209  0.013148  0.014657  -0.010645
# three_g        -0.009366 -0.012065   0.001551 -0.014733 -0.001322  -0.031174
# touch_screen   -0.026999 -0.002638  -0.014368  0.023774 -0.008742   0.021891
# price_range     0.043676  0.000784  -0.029983  0.004666  0.033614   0.149297
#
#               px_width       Ram      sc_h      sc_w  talk_time   three_g  \
# BatteryPow   -0.008402 -0.000653 -0.029959 -0.021421   0.052510  0.011522
# blue         -0.041533  0.026351 -0.002952  0.000613   0.013934 -0.030236
# clock_speed  -0.009476  0.003443 -0.029078 -0.007378  -0.011432 -0.046433
# dual_sim      0.014291  0.041072 -0.011949 -0.016666  -0.039404 -0.014008
# fc           -0.005176  0.015099 -0.011014 -0.012373  -0.006829  0.001793
# four_g        0.007448  0.007313  0.027166  0.037005  -0.046628  0.584246
# int_memory   -0.008335  0.032813  0.037771  0.011731  -0.002790 -0.009366
# m_dep         0.023566 -0.009434 -0.025348 -0.018388   0.017003 -0.012065
# mobile_wt     0.000090 -0.002581 -0.033855 -0.020761   0.006209  0.001551
# n_cores       0.024480  0.004868 -0.000315  0.025826   0.013148 -0.014733
# pc            0.004196  0.028984  0.004938 -0.023819   0.014657 -0.001322
# px_height     0.510664 -0.020352  0.059615  0.043038  -0.010645 -0.031174
# px_width      1.000000  0.004105  0.021599  0.034699   0.006720  0.000350
# Ram           0.004105  1.000000  0.015996  0.035576   0.010820  0.015795
# sc_h          0.021599  0.015996  1.000000  0.506144  -0.017335  0.012033
# sc_w          0.034699  0.035576  0.506144  1.000000  -0.022821  0.030941
# talk_time     0.006720  0.010820 -0.017335 -0.022821   1.000000 -0.042688
# three_g       0.000350  0.015795  0.012033  0.030941  -0.042688  1.000000
# touch_screen -0.001628 -0.030455 -0.020023  0.012720   0.017196  0.013917
# price_range   0.166422  0.916903  0.021039  0.037309   0.024343  0.022504
#
#               touch_screen  price_range
# BatteryPow       -0.010516     0.202970
# blue              0.010061     0.020820
# clock_speed       0.019756    -0.007194
# dual_sim         -0.017117     0.017272
# fc               -0.014828     0.022311
# four_g            0.016758     0.014622
# int_memory       -0.026999     0.043676
# m_dep            -0.002638     0.000784
# mobile_wt        -0.014368    -0.029983
# n_cores           0.023774     0.004666
# pc               -0.008742     0.033614
# px_height         0.021891     0.149297
# px_width         -0.001628     0.166422
# Ram              -0.030455     0.916903
# sc_h             -0.020023     0.021039
# sc_w              0.012720     0.037309
# talk_time         0.017196     0.024343
# three_g           0.013917     0.022504
# touch_screen      1.000000    -0.031578
# price_range      -0.031578     1.000000

# %% [markdown]
# ### 4.4 Splitting the dataset into the Training set ,Validtion set and Test set

# %%
from sklearn.model_selection import train_test_split
#Spilt data to 3 Part(Train,Validation,Test)
 
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size=0.2, 
    shuffle=True,
    random_state=0,
)

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X, 
    y, 
    test_size=0.2, 
    shuffle=True,
    random_state=42,
)

# %%
#See How it spilt

print("X_train shape: {}".format(X_train.shape))
print("X_test shape: {}".format(X_test.shape))
print("X_val shape: {}".format(X_val.shape))
print("y_train shape: {}".format(y_train.shape))
print("y_test shape: {}".format(y_test.shape))
print("y val shape: {}".format(y_val.shape))
# Out:
# X_train shape: (1600, 20)
# X_test shape: (400, 20)
# X_val shape: (400, 20)
# y_train shape: (1600,)
# y_test shape: (400,)
# y val shape: (400,)

# %% [markdown]
# ### 4.5 Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_val = sc.fit_transform(X_val)
X_test = sc.transform(X_test)
